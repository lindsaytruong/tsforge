# %% [markdown]
# # Import Packages

# %%
# Cell 1 — Imports

import pandas as pd
import numpy as np
import plotly.io as pio

# Ensure plotly renders inline
pio.renderers.default = "notebook_connected"

# Import your tsforge modules
from tsforge.plots.charts.plot_timeseries import plot_timeseries

# %% [markdown]
# ## Build sample dataset

# %%
# FAKE DATA 

import numpy as np
import pandas as pd

# For reproducibility
rng = np.random.default_rng(42)

# -----------------------------
# ACTUALS: df_actuals
# -----------------------------
dates = pd.date_range("2020-01-01", periods=90, freq="D")
ids = ["FOODS_1", "BEV_2", "DAIRY_3"]

rows = []
for uid in ids:
    base_level = {
        "FOODS_1": 50,
        "BEV_2": 80,
        "DAIRY_3": 40,
    }[uid]

    seasonal = np.sin(np.linspace(0, 3 * np.pi, len(dates))) * 10
    noise = rng.normal(scale=5, size=len(dates))
    trend = np.linspace(0, 15, len(dates))

    if uid == "DAIRY_3":
        y = base_level + seasonal + noise              # mostly flat-ish
    else:
        y = base_level + seasonal + noise + trend      # trending

    for d, v in zip(dates, y):
        rows.append({
            "unique_id": uid,
            "ds": d,
            "y": float(max(v, 0.0)),   # no negatives
        })

df_actuals = pd.DataFrame(rows)

# -----------------------------
# FORECAST: df_fcst (single model + 80/95 PIs)
# -----------------------------
h = 14
fc_dates = pd.date_range(df_actuals["ds"].max() + pd.Timedelta(days=1),
                         periods=h, freq="D")

rows = []
for uid in ids:
    sub = df_actuals[df_actuals["unique_id"] == uid]
    base_last = sub["y"].iloc[-1]

    seasonal = np.sin(np.linspace(0, 2 * np.pi, h)) * 8
    noise = rng.normal(scale=3, size=h)
    trend = np.linspace(0, 5, h)

    mean = base_last + seasonal + trend
    yhat = mean + noise

    lo80 = yhat - 5
    hi80 = yhat + 5
    lo95 = yhat - 8
    hi95 = yhat + 8

    for d, yh, lo8, hi8, lo9, hi9 in zip(fc_dates, yhat, lo80, hi80, lo95, hi95):
        rows.append({
            "unique_id": uid,
            "ds": d,
            "yhat": float(yh),
            "yhat-lo-80": float(lo8),
            "yhat-hi-80": float(hi8),
            "yhat-lo-95": float(lo9),
            "yhat-hi-95": float(hi9),
        })

df_fcst = pd.DataFrame(rows)

# -----------------------------
# FORECAST: df_fcst_multi (two models)
# -----------------------------
rows = []
for uid in ids:
    base_fc = df_fcst[df_fcst["unique_id"] == uid].copy()

    for model_name, bias in [("Naive", 0.0), ("ML", 3.0)]:
        yhat = base_fc["yhat"] + bias

        for (_, r), yh in zip(base_fc.iterrows(), yhat):
            rows.append({
                "unique_id": uid,
                "ds": r["ds"],
                "model": model_name,
                "yhat": float(yh),
                "yhat-lo-80": float(yh - 5),
                "yhat-hi-80": float(yh + 5),
            })

df_fcst_multi = pd.DataFrame(rows)

# -----------------------------
# EVENTS: events_df
# -----------------------------
events_df = pd.DataFrame({
    "ds": pd.to_datetime([
        "2020-01-15",   # in-history promo
        "2020-02-14",   # Valentine's
        "2020-03-01",   # price change
        "2020-04-01",   # event during forecast horizon
    ]),
    "event": ["Promo A", "Valentine's", "Price Change", "Spring Reset"],
})

# -----------------------------
# ANOMALIES: anoms_df
# -----------------------------
anom_rows = []
for uid in ids:
    sub = df_actuals[df_actuals["unique_id"] == uid]
    # pick 2 random dates from the middle of history
    sample_dates = sub["ds"].iloc[20:70].sample(2, random_state=hash(uid) % 2**32)
    for d in sample_dates:
        anom_rows.append({"unique_id": uid, "ds": d})

anoms_df = pd.DataFrame(anom_rows)

# %%
events_df.head(2)
# Out:
#           ds        event
# 0 2020-01-15      Promo A
# 1 2020-02-14  Valentine's

# %% [markdown]
# ## Test overlay

# %%
# Cell 3 — overlay test (FA theme)

fig = plot_timeseries(
    df=df_actuals,
    forecast=df_fcst,
    id_col="unique_id",
    date_col="ds",
    value_col="y",
    level=[80, 95],
    events_global=events_df,
    anomalies=anoms_df,
    mode="overlay",
    theme="fa",
)
fig
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="a3f35a15-e620-44c9-92a5-52f97b20164b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a3f35a15-e620-44c9-92a5-52f97b20164b")) {                    Plotly.newPlot(                        "a3f35a15-e620-44c9-92a5-52f97b20164b",                        [{"hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUJGVUDK1l05fMdWQGYG1lKyJFhA4\u002faoraZrWEBNHJqujiRYQB8cNbow1ldAXSKwf075VkA+tgHRiGpWQEPUOyVlp1ZA4\u002fr84HktU0BoFZ5C4OdUQEO9ApnBplVADrMB172NVkCAqCeIDhRXQA=="},"type":"scatter"},{"fill":"tonexty","fillcolor":"rgba(46,134,171,0.22)","hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUJGWUDK1l05fMdaQGYG1lKyJFxA4\u002faoraZrXEBNHJqujiRcQB8cNbow1ltAXSKwf075WkA+tgHRiGpaQEPUOyVlp1pA4\u002fr84HktV0BoFZ5C4OdYQEO9ApnBpllADrMB172NWkCAqCeIDhRbQA=="},"type":"scatter"},{"hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUIGVkDK1l05fIdXQGYG1lKy5FhA4\u002faoraYrWUBNHJqujuRYQB8cNbowllhAXSKwf065V0A+tgHRiCpXQEPUOyVlZ1dA4\u002fr84HntU0BoFZ5C4KdVQEO9ApnBZlZADrMB171NV0CAqCeIDtRXQA=="},"type":"scatter"},{"fill":"tonexty","fillcolor":"rgba(46,134,171,0.22)","hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUKGWEDK1l05fAdaQGYG1lKyZFtA4\u002faoraarW0BNHJqujmRbQB8cNbowFltAXSKwf045WkA+tgHRiKpZQEPUOyVl51lA4\u002fr84HltVkBoFZ5C4CdYQEO9ApnB5lhADrMB173NWUCAqCeIDlRaQA=="},"type":"scatter"},{"line":{"color":"#2E86AB","width":2},"mode":"lines","name":"BEV_2","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:0 ...

# %% [markdown]
# ## Test Facet

# %%
# Cell 4 — facet mode test

fig = plot_timeseries(
    df_actuals,
    forecast=df_fcst,
    id_col="unique_id",
    date_col="ds",
    value_col="y",
    events_global=events_df,
    anomalies=anoms_df,
    level=[80, 95],
    mode="facet",
    theme="fa",
)
fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="0a247fa1-f56f-4407-b321-6ea4769d83cd" class="plotly-graph-div" style="height:840px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0a247fa1-f56f-4407-b321-6ea4769d83cd")) {                    Plotly.newPlot(                        "0a247fa1-f56f-4407-b321-6ea4769d83cd",                        [{"hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUJGVUDK1l05fMdWQGYG1lKyJFhA4\u002faoraZrWEBNHJqujiRYQB8cNbow1ldAXSKwf075VkA+tgHRiGpWQEPUOyVlp1ZA4\u002fr84HktU0BoFZ5C4OdUQEO9ApnBplVADrMB172NVkCAqCeIDhRXQA=="},"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"tonexty","fillcolor":"rgba(46,134,171,0.22)","hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUJGWUDK1l05fMdaQGYG1lKyJFxA4\u002faoraZrXEBNHJqujiRcQB8cNbow1ltAXSKwf075WkA+tgHRiGpaQEPUOyVlp1pA4\u002fr84HktV0BoFZ5C4OdYQEO9ApnBpllADrMB172NWkCAqCeIDhRbQA=="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUIGVkDK1l05fIdXQGYG1lKy5FhA4\u002faoraYrWUBNHJqujuRYQB8cNbowllhAXSKwf065V0A+tgHRiCpXQEPUOyVlZ1dA4\u002fr84HntU0BoFZ5C4KdVQEO9ApnBZlZADrMB171NV0CAqCeIDtRXQA=="},"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"tonexty","fillcolor":"rgba(46,134,171,0.22)","hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUKGWEDK1l05fAdaQGYG1lKyZFtA4\u002faoraarW0BNHJqujmRbQB8cNbowFltAXSKwf045WkA+tgHRiKpZQEPUOyVl51lA4\u002fr84HltVkBoFZ5C4CdYQEO9ApnB5lhADrMB173NWUCAqCeIDlRaQA=="},"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#2E86AB","width":2},"mode":"lines","name":"BEV_2","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02 ...

# %% [markdown]
# ## Test Dropdown

# %%
# Cell 5 — dropdown mode test

fig = plot_timeseries(
    df_actuals,
    forecast=df_fcst,
    id_col="unique_id",
    date_col="ds",
    value_col="y",
    level=[80, 95],
    events_global=events_df,
    anomalies=anoms_df,
    mode="dropdown",
    theme="fa",
)
fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="601a0634-8de5-4560-800c-6394fe657537" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("601a0634-8de5-4560-800c-6394fe657537")) {                    Plotly.newPlot(                        "601a0634-8de5-4560-800c-6394fe657537",                        [{"hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"visible":true,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUJGVUDK1l05fMdWQGYG1lKyJFhA4\u002faoraZrWEBNHJqujiRYQB8cNbow1ldAXSKwf075VkA+tgHRiGpWQEPUOyVlp1ZA4\u002fr84HktU0BoFZ5C4OdUQEO9ApnBplVADrMB172NVkCAqCeIDhRXQA=="},"type":"scatter"},{"fill":"tonexty","fillcolor":"rgba(46,134,171,0.22)","hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"visible":true,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUJGWUDK1l05fMdaQGYG1lKyJFxA4\u002faoraZrXEBNHJqujiRcQB8cNbow1ltAXSKwf075WkA+tgHRiGpaQEPUOyVlp1pA4\u002fr84HktV0BoFZ5C4OdYQEO9ApnBpllADrMB172NWkCAqCeIDhRbQA=="},"type":"scatter"},{"hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"visible":true,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUIGVkDK1l05fIdXQGYG1lKy5FhA4\u002faoraYrWUBNHJqujuRYQB8cNbowllhAXSKwf065V0A+tgHRiCpXQEPUOyVlZ1dA4\u002fr84HntU0BoFZ5C4KdVQEO9ApnBZlZADrMB171NV0CAqCeIDtRXQA=="},"type":"scatter"},{"fill":"tonexty","fillcolor":"rgba(46,134,171,0.22)","hoverinfo":"skip","line":{"width":0},"mode":"lines","showlegend":false,"visible":true,"x":["2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00"],"y":{"dtype":"f8","bdata":"a+QE\u002fUKGWEDK1l05fAdaQGYG1lKyZFtA4\u002faoraarW0BNHJqujmRbQB8cNbowFltAXSKwf045WkA+tgHRiKpZQEPUOyVl51lA4\u002fr84HltVkBoFZ5C4CdYQEO9ApnB5lhADrMB173NWUCAqCeIDlRaQA=="},"type":"scatter"},{"line":{"color":"#2E86AB","width":2},"mode":"lines","showlegend":false,"visible":true,"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","20 ...

# %% [markdown]
# ## Test Smoothing

# %%
# Cell 6 — smoothing test

fig = plot_timeseries(
    df_actuals,
    id_col="unique_id",
    date_col="ds",
    value_col="y",
    smooth_window=7,
    mode="overlay",
    theme="fa",
)
fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="821e0f6b-d437-47be-ae7f-ed507788fc4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("821e0f6b-d437-47be-ae7f-ed507788fc4f")) {                    Plotly.newPlot(                        "821e0f6b-d437-47be-ae7f-ed507788fc4f",                        [{"line":{"color":"#2E86AB","width":2},"mode":"lines","name":"BEV_2","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00"],"y":{"dtype":"f8","bdata":"udoeWezUVECz+UQS6y5UQFGGJGOnFFRAwKYqlsTOVEDf9BxlQhZTQA284p4cqlNA8t3ToUgVVECtxGxxiLxUQDFFka7XtVZAIda6\u002fgxJVUC5PKQO1iBWQPv9AdpkYlhALwPmcNdyVkDp8zrKNOxXQOcwH2DD6VVArrAwQ\u002fXfVkDCPBT3svdVQL5RPKUbulZA0Ja4QGgrWECrXYa\u002f5+ZUQAf7E6lRhVdABApQLukqV0AsgsRni\..."},"type":"scatter"},{"line":{"color":"#F6C85F","width":2},"mode":"lines","name":"DAIRY_3","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T ...

# %% [markdown]
# ## Test Grouping / Aggregation

# %%
# Cell 7 — Test group_col / aggregation

df_grouped = df_actuals.copy()
df_grouped["department"] = df_grouped["unique_id"].str.split("_").str[0]

fig = plot_timeseries(
    df_grouped,
    id_col="unique_id",
    date_col="ds",
    value_col="y",
    group_col="department",
    agg="mean",
    mode="overlay",
    theme="fa",
)
fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="a9b6f459-a787-4ee4-ad42-147cf57186f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a9b6f459-a787-4ee4-ad42-147cf57186f9")) {                    Plotly.newPlot(                        "a9b6f459-a787-4ee4-ad42-147cf57186f9",                        [{"line":{"color":"#2E86AB","width":2},"mode":"lines","name":"BEV","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00"],"y":{"dtype":"f8","bdata":"udoeWezUVECz+UQS6y5UQFGGJGOnFFRAwKYqlsTOVEDf9BxlQhZTQA284p4cqlNA8t3ToUgVVECtxGxxiLxUQDFFka7XtVZAIda6\u002fgxJVUC5PKQO1iBWQPv9AdpkYlhALwPmcNdyVkDp8zrKNOxXQOcwH2DD6VVArrAwQ\u002fXfVkDCPBT3svdVQL5RPKUbulZA0Ja4QGgrWECrXYa\u002f5+ZUQAf7E6lRhVdABApQLukqV0AsgsRni\..."},"type":"scatter"},{"line":{"color":"#F6C85F","width":2},"mode":"lines","name":"DAIRY","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:0 ...

# %% [markdown]
# ## Test Themes

# %%
# Cell 8 — Test all themes

for t in ["fa", "mckinsey", "minimal", "dark"]:
    print("Theme:", t)
    fig = plot_timeseries(
        df_actuals,
        id_col="unique_id",
        date_col="ds",
        value_col="y",
        mode="overlay",
        theme=t,
    )
    fig.show()
# Out:
# Theme: fa
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="9c13220e-8df8-4f8e-81de-6c0323b131e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9c13220e-8df8-4f8e-81de-6c0323b131e8")) {                    Plotly.newPlot(                        "9c13220e-8df8-4f8e-81de-6c0323b131e8",                        [{"line":{"color":"#2E86AB","width":2},"mode":"lines","name":"BEV_2","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00"],"y":{"dtype":"f8","bdata":"udoeWezUVECz+UQS6y5UQFGGJGOnFFRAwKYqlsTOVEDf9BxlQhZTQA284p4cqlNA8t3ToUgVVECtxGxxiLxUQDFFka7XtVZAIda6\u002fgxJVUC5PKQO1iBWQPv9AdpkYlhALwPmcNdyVkDp8zrKNOxXQOcwH2DD6VVArrAwQ\u002fXfVkDCPBT3svdVQL5RPKUbulZA0Ja4QGgrWECrXYa\u002f5+ZUQAf7E6lRhVdABApQLukqV0AsgsRni\..."},"type":"scatter"},{"line":{"color":"#F6C85F","width":2},"mode":"lines","name":"DAIRY_3","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T ...
# Theme: mckinsey
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 5
#       3 for t in ["fa", "mckinsey", "minimal", "dark"]:
#       4     print("Theme:", t)
# ----> 5     fig = plot_timeseries(
#       6         df_actuals,
#       7         id_col="unique_id",
#       8         date_col="ds",
#       9         value_col="y",
#      10         mode="overlay",
#      11         theme=t,
#      12     )
#      13     fig.show()
#
# File ~\Documents\GitHub\tsforge\src\tsforge\plots\charts\plot_timeseries.py:238, in plot_timeseries(df, id_col, date_col, value_col, group_col, agg, freq, ids, max_ids, smooth_window, forecast, forecast_value_col, level, lo_pattern, hi_pattern, events, events_global, events_local, event_label_col, events_config, anomalies, anomaly_flag_value, anomalies_config, mode, wrap, theme, style, engine)
#     233     raise ValueError("mode must be one of: overlay, facet, dropdown")
#     235 # ------------------------------------------------------------------
#     236 # 7) Apply theme + titles
#     237 # ------------------------------------------------------------------
# --> 238 fig = apply_theme(fig, theme)
#     240 if style:
#     241     if "title" in style:
#
# File ~\Documents\GitHub\tsforge\src\tsforge\plots\core\theme.py:59, in apply_theme(fig, theme)
#      51 t = THEMES.get(theme, THEMES["fa"])
#      53 fig.update_layout(
#      54     font=dict(family=t["font"], size=t["font_size"]),
#      55     plot_bgcolor=t["background"],
#      56     paper_bgcolor=t["background"],
#      57 )
# ---> 59 fig.update_xaxes(showgrid=True, gridcolor=t["grid_color"], color=t["axis_color"])
#      60 fig.update_yaxes(showgrid=True, gridcolor=t["grid_color"], color=t["axis_color"])
#      62 return fig
#
# KeyError: 'axis_color'
